# %%
# IMPORTS
import os
import numpy as np
from utils.data import read_stock_history, normalize
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import seaborn as sns
import tensorflow as tf
from model.ddpg.actor import ActorNetwork
from model.ddpg.critic import CriticNetwork
from model.ddpg.ddpg import DDPG
from model.ornstein_uhlenbeck import OrnsteinUhlenbeckActionNoise
from model.td3.actor import TD3ActorNetwork
from model.td3.critic import TD3CriticNetwork
from model.td3.td3 import TD3
from stock_trading import StockActor, StockCritic, TD3StockActor, TD3StockCritic, obs_normalizer, get_model_path, get_result_path, test_model, get_variable_scope, test_model_multiple
from environment.portfolio import PortfolioEnv, MultiActionPortfolioEnv, max_drawdown, sharpe, sortino, create_close_dataframe, convert_prices
import tflearn
from stock_trading import test_portfolio_selection, test_portfolio_selection_multiple, plot_weights, plot_portfolio_values, results_table, results_table_row, returns_from_cumulative, extract_from_infos, returns_from_cumulative

from technical_indicators.technical_indicators import full_rmr_moving_average, olmar_moving_average

tf.__version__
print("Imports Complete")
# Out:
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Imports Complete

# %%
# common settings
batch_size = 64
action_bound = 1.
tau = 1e-3

models = []
model_names = []
framework_lst = ['TD3']
window_length_lst = [3, 7, 11, 14]
maximum_window = max(window_length_lst)
predictor_type_lst = ['lstm']
use_batch_norm = True
log_return = True
technical_indicators_flag = True
load_technical_indicators = True

# %%
# Stock History
dataset_name = 'nyse_n'
history, assets, date_list = read_stock_history(filepath='utils/datasets/{}.h5'.format(dataset_name))
history = history[:, :, :4]
nb_classes = len(history) + 1
print("Dataset: {}".format(dataset_name))
print("Assets: {}".format(assets))
print("Stock History Shape: {}".format(history.shape))
print("Full Stock History Date Range: {} -> {}".format(date_list[0], date_list[-1]))
# Out:
# Dataset: nyse_n
# Assets: ['ahp', 'alcoa', 'amer_brands', 'coke', 'comm_metals', 'dow_chem', 'Dupont', 'ford', 'ge', 'gm', 'hp', 'ibm', 'ingersoll', 'jnj', 'kimb-clark', 'kin_ark', 'Kodak', 'merck', 'mmm', 'morris', 'p_and_g', 'schlum', 'sher_will']
# Stock History Shape: (23, 6430, 2)
# Full Stock History Date Range: 02/01/1985 -> 30/06/2010

# %%
# Training/Testing Date Range
full_length = len(date_list)
train_test_ratio = 6/7
train_start_date = date_list[maximum_window]
train_end_date = date_list[(int)(full_length * train_test_ratio)-1]
test_start_date = date_list[(int)(full_length * train_test_ratio)]
test_end_date = date_list[full_length-2]
print("Training Date Range: {} -> {} ({} Steps)".format(train_start_date, train_end_date, 
                                                    (int)(date_list.index(train_end_date) - date_list.index(train_start_date))))
print("Testing Date Range: {} -> {} ({} Steps)".format(test_start_date, test_end_date, 
                                                    (int)(date_list.index(test_end_date) - date_list.index(test_start_date))))
# Out:
# Training Date Range: 22/01/1985 -> 02/11/2006 (5496 Steps)
# Testing Date Range: 03/11/2006 -> 29/06/2010 (917 Steps)

# %%
# Generate Technical Indicators
def GenerateTechnicalIndicators(window_length, debug = False):
    if debug:
        print('history.shape: {}'.format(history.shape))

    # Check if just close is fed or full dataset
    if history.shape[2] == 4:
        # Get Close
        history_close = history[:, :, 3]
    elif history.shape[2] == 2:
        # Assume the one sent is the close price
        history_close = history[:, :, 1]

    if debug:
        print('history_close.shape: {}'.format(history_close.shape))

    # Add Technical Indicators to be included in state
    if technical_indicators_flag:
        technical_indicator_history = []

        # Close Price DataFrame for on-line Portfolio Selection
        temp_close_df = create_close_dataframe(history, assets, date_list)
        temp_close_df = convert_prices(temp_close_df, 'raw', True)    
        if debug:
            print('temp_close_df.shape: {}'.format(temp_close_df.shape))

        rmr_moving_average_df = full_rmr_moving_average(temp_close_df, window_length)
        for i in range(len(assets)):
            # Create List
            ti = []
            #ti.append([olmar_moving_average(temp_close_df[assets[i]], window_length)]) # Based on OLMAR
            ti.append([rmr_moving_average_df[assets[i]]]) # Based on RMR

            # Turn to Array
            ti = np.vstack(ti)

            ti_reshaped = []
            for j in range(temp_close_df.shape[0]):
                ti_reshaped.append(ti[:, j])   

            technical_indicator_history.append(ti_reshaped)

        technical_indicator_history = np.array(technical_indicator_history)    
        if debug:
            print('technical_indicators.shape: {}'.format(technical_indicator_history.shape)) 
    else:
        technical_indicator_history = None
        
    return technical_indicator_history

# %%
if technical_indicators_flag:
    if load_technical_indicators:
        # Load Technical Indicators dataset
        ti_dict = np.load('technical_indicators/dictionaries/ti_dict-{}-rmr.npy'.format(dataset_name),allow_pickle='TRUE').item()
    else:
        ti_dict = {}
        for window_length in window_length_lst:
            technical_indicator_history = GenerateTechnicalIndicators(window_length)
            ti_dict[window_length] = technical_indicator_history
        np.save('technical_indicators/dictionaries/ti_dict-{}-rmr.npy'.format(dataset_name), ti_dict)

# %%
# instantiate environment
for framework in framework_lst:
    for window_length in window_length_lst:
        for predictor_type in predictor_type_lst:
            if technical_indicators_flag:
                name = '{}_{}_window_{}_predictor_{}_rmr-pred'.format(dataset_name, framework, window_length, predictor_type)
            else:
                name = '{}_{}_window_{}_predictor_{}'.format(dataset_name, framework, window_length, predictor_type)
            model_names.append(name)
            tf.reset_default_graph()
            sess = tf.Session()
            tflearn.config.init_training_mode()
            action_dim = [nb_classes]
            if technical_indicators_flag:
                technical_indicator_history = ti_dict[window_length]
                state_dim = [nb_classes, window_length+technical_indicator_history.shape[2]]
            else:
                state_dim = [nb_classes, window_length]

            variable_scope = get_variable_scope(dataset_name, framework, window_length, predictor_type, 
                                                use_batch_norm, technical_indicators_flag)

            with tf.variable_scope(variable_scope):

                if(framework == 'DDPG'):
                    actor = StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, 
                                       predictor_type, use_batch_norm)
                    critic = StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                             learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(), 
                             predictor_type=predictor_type, use_batch_norm=use_batch_norm)
                    actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

                    model_save_path = get_model_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, technical_indicators_flag)
                    summary_path = get_result_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, technical_indicators_flag)

                    ddpg_model = DDPG(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer,
                                      log_return=log_return, config_file='config/stock.json', 
                                      model_save_path=model_save_path, summary_path=summary_path)
                    ddpg_model.initialize(load_weights=True, verbose=True)
                    models.append(ddpg_model)

                elif(framework == 'TD3'):
                    actor = TD3StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, 
                                          predictor_type, use_batch_norm)
                    critic = TD3StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                             learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(),
                             predictor_type=predictor_type, use_batch_norm=use_batch_norm,
                               inp_actions=actor.scaled_out)
                    actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

                    model_save_path = get_model_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, technical_indicators_flag)
                    summary_path = get_result_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, technical_indicators_flag)

                    td3_model = TD3(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer, 
                                    log_return=log_return, config_file='config/stock.json', 
                                    model_save_path=model_save_path, summary_path=summary_path)
                    td3_model.initialize(load_weights=True, verbose=True)
                    models.append(td3_model)
# Out:
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/layers/core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/layers/recurrent.py:69: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/layers/recurrent.py:553: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/initializations.py:174: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/initializations.py:75: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/actor.py:45: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/actor.py:63: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/actor.py:66: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:20: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:25: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:69: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:71: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from weights/nyse_n/TD3/lstm/window_3/batch_norm/technical_indicators/checkpoint.ckpt
# Loading is_training:0 from checkpoint. Name: is_training
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_2/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_3/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta1_power:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta1_power
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta2_power:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta2_power
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/beta/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/gamma/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_1/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/FullyConnected_2/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/target_critic/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta1_power_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta1_power_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta2_power_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta2_power_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/Variable:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/Variable
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/Variable_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/Variable_1
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta1_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta1_power_2
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta2_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/beta2_power_2
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3
# Loading nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_3_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_2
# ...
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_3

# %%
model_names
# Out:
# ['nyse_n_TD3_window_3_predictor_lstm_rmr-pred',
#  'nyse_n_TD3_window_7_predictor_lstm_rmr-pred',
#  'nyse_n_TD3_window_11_predictor_lstm_rmr-pred',
#  'nyse_n_TD3_window_14_predictor_lstm_rmr-pred']

# %% [markdown]
# #### IN SAMPLE

# %%
# Compiled Results
in_full_model_names = []
in_full_models = []
in_portfolio_values_list = [] 

for window_length in window_length_lst:
    model_names_subset = []
    models_subset = []
    for i in range(len(model_names)):
        if 'window_{}'.format(window_length) in model_names[i]:
            model_names_subset.append(model_names[i])
            models_subset.append(models[i])
            
    if technical_indicators_flag:
        env = MultiActionPortfolioEnv(history, assets, model_names_subset, date_list, start_date=train_start_date, 
                              end_date=train_end_date, window_length=window_length, 
                                  technical_indicators_flag=technical_indicators_flag, 
                                  technical_indicator_history=ti_dict[window_length])
    else:
        env = MultiActionPortfolioEnv(history, assets, model_names_subset, date_list, start_date=train_start_date, 
                              end_date=train_end_date, window_length=window_length)

    _, info_list, _, _ = test_model_multiple(env, models_subset)
    
    # Add to results
    for i in range(len(model_names_subset)):
        in_full_model_names.append(model_names_subset[i])
        in_full_models.append(models_subset[i])     
        in_portfolio_values_list.append(extract_from_infos(info_list, model_names_subset[i]))
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
in_dates = extract_from_infos(info_list, 'date')

# %% [markdown]
# ##### OLPS

# %%
# Set Up Environment
env = PortfolioEnv(history, assets, date_list, start_date=train_start_date, 
                              end_date=train_end_date, window_length=3, olps=True)

in_olps_model_names = ['CRP', 'BCRP', 'OLMAR', 'PAMR', 'RMR', 'WMAMR', 'EG', 'ONS', 'UP']
observations_list, in_olps_portfolio_values_list, weights_list, dates = test_portfolio_selection_multiple(env, 
                                                                                                in_olps_model_names)
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# =========CRP=========
# len(weights_array): 6430
# =========BCRP=========
# len(weights_array): 5497
# =========OLMAR=========
# len(weights_array): 5497
# =========PAMR=========
# len(weights_array): 5497
# =========RMR=========
# len(weights_array): 5497
# =========WMAMR=========
# len(weights_array): 5497
# =========EG=========
# len(weights_array): 5497
# =========ONS=========
# len(weights_array): 5497
# =========UP=========
# len(weights_array): 5497

# %%
log_y = True

df = pd.DataFrame()
df["Date"] = in_dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')

# OLPS
for i in range(len(in_olps_model_names)):
    df[in_olps_model_names[i]] = in_olps_portfolio_values_list[i]
    plt.plot(df[in_olps_model_names[i]], label=in_olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(in_full_model_names)):
    df[in_full_model_names[i]] = in_portfolio_values_list[i]
    plt.plot(df[in_full_model_names[i]], label=in_full_model_names[i], 
             linewidth=2)
    
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(in_dates), 200))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.30, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
# RESULT
df = pd.DataFrame(columns=['Portfolio', 'Average Daily Yield (%)', 'Sharpe Ratio (%)', 'Sortino Ratio (%)', 'Maximum Drawdown (%)',
                           'Final Portfolio Value'])
for i in range(len(in_full_model_names)):
    df = results_table_row(df, in_full_model_names[i],
                           returns_from_cumulative(in_portfolio_values_list[i]),
                           in_portfolio_values_list[i])

for i in range(len(in_olps_model_names)):
    df = results_table_row(df, in_olps_model_names[i],
                           returns_from_cumulative(in_olps_portfolio_values_list[i]),
                           in_olps_portfolio_values_list[i])

# Market
#df = results_table_row(df, 'market_value',
#                           returns_from_cumulative(extract_from_infos(info_list, 'market_value')),
#                           extract_from_infos(info_list, 'market_value'))
df
# Out:
#                                        Portfolio  Average Daily Yield (%)  \
# 0    nyse_n_TD3_window_3_predictor_lstm_rmr-pred                   0.6655
# 1    nyse_n_TD3_window_7_predictor_lstm_rmr-pred                   0.4841
# 2   nyse_n_TD3_window_11_predictor_lstm_rmr-pred                   0.5230
# 3   nyse_n_TD3_window_14_predictor_lstm_rmr-pred                   0.6095
# 4                                            CRP                   0.0618
# 5                                           BCRP                   0.0857
# 6                                          OLMAR                   0.3952
# 7                                           PAMR                   0.2754
# 8                                            RMR                   0.4058
# 9                                          WMAMR                   0.3607
# 10                                            EG                   0.0615
# 11                                           ONS                   0.0581
# 12                                            UP                   0.0611
#
#     Sharpe Ratio (%)  Sortino Ratio (%)  Maximum Drawdown (%)  \
# 0            25.5671            47.1270               33.8889
# 1            28.3502            48.9965               27.0313
# 2            26.1601            45.4497               38.6743
# 3            18.6156            32.4852               55.2064
# 4             6.2972             8.0582               31.5102
# 5             6.4699             9.0536               44.4480
# 6            13.9416            21.1243               40.7201
# 7            10.5902            16.0863               43.3713
# 8            14.3401            21.9369               39.0915
# 9            13.2753            19.1172               42.0152
# 10            6.2556             8.0046               31.5878
# 11            4.7209             6.7931               32.7303
# 12            6.2443             7.9873               31.3860
#
#     Final Portfolio Value
# 0            1.153359e+15
# 1            1.567769e+11
# 2            9.366817e+11
# 3            1.953909e+13
# 4            2.305000e+01
# 5            6.877000e+01
# 6            2.883127e+08
# 7            6.174529e+05
# 8            5.189310e+08
# 9            5.314232e+07
# 10           2.271200e+01
# 11           1.627700e+01
# 12           2.224300e+01

# %% [markdown]
# #### OUT OF SAMPLE

# %%
# Compiled Results
full_model_names = []
full_models = []
portfolio_values_list = [] 

for window_length in window_length_lst:
    model_names_subset = []
    models_subset = []
    for i in range(len(model_names)):
        if 'window_{}'.format(window_length) in model_names[i]:
            model_names_subset.append(model_names[i])
            models_subset.append(models[i])
            
    if technical_indicators_flag:
        env = MultiActionPortfolioEnv(history, assets, model_names_subset, date_list, start_date=test_start_date, 
                              end_date=test_end_date, window_length=window_length, 
                                  technical_indicators_flag=technical_indicators_flag, 
                                  technical_indicator_history=ti_dict[window_length])
    else:
        env = MultiActionPortfolioEnv(history, assets, model_names_subset, date_list, start_date=test_start_date, 
                              end_date=test_end_date, window_length=window_length)

    _, info_list, _, _ = test_model_multiple(env, models_subset)
    
    # Add to results
    for i in range(len(model_names_subset)):
        full_model_names.append(model_names_subset[i])
        full_models.append(models_subset[i])     
        portfolio_values_list.append(extract_from_infos(info_list, model_names_subset[i]))
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# #### Plot

# %%
log_y = False
df = pd.DataFrame()
dates = extract_from_infos(info_list, 'date')
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')
for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
    plt.plot(df[full_model_names[i]], label=full_model_names[i])
df['market_value'] = extract_from_infos(info_list, 'market_value')
plt.plot(df['market_value'], label='market_value')
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.30, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
# RESULT
df = pd.DataFrame(columns=['Portfolio', 'Average Daily Yield (%)', 'Sharpe Ratio (%)', 'Sortino Ratio (%)', 'Maximum Drawdown (%)',
                           'Final Portfolio Value'])
for i in range(len(full_model_names)):
    df = results_table_row(df, full_model_names[i],
                           returns_from_cumulative(portfolio_values_list[i]),
                           portfolio_values_list[i])
# Market
df = results_table_row(df, 'market_value',
                           returns_from_cumulative(extract_from_infos(info_list, 'market_value')),
                           extract_from_infos(info_list, 'market_value'))
df
# Out:
#                                       Portfolio  Average Daily Yield (%)  \
# 0   nyse_n_TD3_window_3_predictor_lstm_rmr-pred                   0.1950
# 1   nyse_n_TD3_window_7_predictor_lstm_rmr-pred                   0.1032
# 2  nyse_n_TD3_window_11_predictor_lstm_rmr-pred                  -0.0126
# 3  nyse_n_TD3_window_14_predictor_lstm_rmr-pred                   0.1511
# 4                                  market_value                   0.0184
#
#    Sharpe Ratio (%)  Sortino Ratio (%)  Maximum Drawdown (%)  \
# 0            6.8768            11.1452               33.1254
# 1            3.2327             4.4481               62.6060
# 2           -0.2487            -0.2709               94.1729
# 3            3.5843             5.2643               79.8013
# 4            0.9736             1.2451               62.6889
#
#    Final Portfolio Value
# 0                  4.174
# 1                  1.665
# 2                  0.253
# 3                  1.838
# 4                  1.005

# %% [markdown]
# #### Compare with online-portfolio selection

# %%
# Set Up Environment
env = PortfolioEnv(history, assets, date_list, start_date=test_start_date, 
                              end_date=test_end_date, window_length=3, olps=True)

olps_model_names = ['CRP', 'BCRP', 'OLMAR', 'PAMR', 'RMR', 'WMAMR', 'EG', 'ONS', 'UP']
observations_list, olps_portfolio_values_list, weights_list, dates = test_portfolio_selection_multiple(env, 
                                                                                                olps_model_names)
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# =========CRP=========
# len(weights_array): 6430
# =========BCRP=========
# len(weights_array): 918
# =========OLMAR=========
# len(weights_array): 918
# =========PAMR=========
# len(weights_array): 918
# =========RMR=========
# len(weights_array): 918
# =========WMAMR=========
# len(weights_array): 918
# =========EG=========
# len(weights_array): 918
# =========ONS=========
# len(weights_array): 918
# =========UP=========
# len(weights_array): 918

# %%
# Plot Together
log_y = False
df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    df[olps_model_names[i]] = olps_portfolio_values_list[i]
    plt.plot(df[olps_model_names[i]], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
    plt.plot(df[full_model_names[i]], label=full_model_names[i], 
             linewidth=2)
    
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.30, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
# Plot Together
log_y = True
df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    df[olps_model_names[i]] = olps_portfolio_values_list[i]
    plt.plot(df[olps_model_names[i]], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
    plt.plot(df[full_model_names[i]], label=full_model_names[i], 
             linewidth=2)
    
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
models = full_model_names + olps_model_names
portfolio_values = portfolio_values_list + olps_portfolio_values_list
results_table(models, portfolio_values)
# Out:
#                                        Portfolio  Average Daily Yield (%)  \
# 0    nyse_n_TD3_window_3_predictor_lstm_rmr-pred                   0.1950
# 1    nyse_n_TD3_window_7_predictor_lstm_rmr-pred                   0.1032
# 2   nyse_n_TD3_window_11_predictor_lstm_rmr-pred                  -0.0126
# 3   nyse_n_TD3_window_14_predictor_lstm_rmr-pred                   0.1511
# 4                                            CRP                   0.0145
# 5                                           BCRP                   0.1139
# 6                                          OLMAR                   0.2199
# 7                                           PAMR                   0.1815
# 8                                            RMR                   0.2103
# 9                                          WMAMR                   0.0236
# 10                                            EG                   0.0133
# 11                                           ONS                   0.0057
# 12                                            UP                   0.0131
#
#     Sharpe Ratio (%)  Sortino Ratio (%)  Maximum Drawdown (%)  \
# 0             6.8768            11.1452               33.1254
# 1             3.2327             4.4481               62.6060
# 2            -0.2487            -0.2709               94.1729
# 3             3.5843             5.2643               79.8013
# 4             0.7684             0.9817               63.2787
# 5             3.7366             5.8033               73.2078
# 6             3.4137             4.6782               91.4425
# 7             3.6662             5.0717               79.0335
# 8             3.2596             4.5271               91.6121
# 9             0.3772             0.4779               94.6415
# 10            0.7114             0.9070               63.1222
# 11            0.0757             0.0852               96.1809
# 12            0.6964             0.8923               63.4904
#
#     Final Portfolio Value
# 0                   4.174
# 1                   1.665
# 2                   0.253
# 3                   1.838
# 4                   0.970
# 5                   1.876
# 6                   1.206
# 7                   1.797
# 8                   1.104
# 9                   0.206
# 10                  0.962
# 11                  0.072
# 12                  0.958

# %% [markdown]
# --------------
# ##### Plot two models against each other

# %%
#full_model_names

# %%
# Best Performing models in-sample: (one DDPG and one TD3)
model_names_best_insample = ['nyse_n_DDPG_window_7_predictor_lstm', 'nyse_n_TD3_window_14_predictor_lstm']

# %%
# Plot Together
log_y = False
df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    df[olps_model_names[i]] = olps_portfolio_values_list[i]
    plt.plot(df[olps_model_names[i]], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
for name in model_names_best_insample:
    plt.plot(df[name], label=name, 
             linewidth=2.5)
    
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nyse_n_DDPG_window_7_predictor_lstm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-86d38281a729> in <module>
#      24     df[full_model_names[i]] = portfolio_values_list[i]
#      25 for name in model_names_best_insample:
# ---> 26     plt.plot(df[name], label=name,
#      27              linewidth=2.5)
#      28
#
# ~/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nyse_n_DDPG_window_7_predictor_lstm'

# %% [markdown]
# ----------------
# ## Rolling Analysis
# 1. Rolling Average Daily Yield (%)
# 2. Rolling Sharpe Ratio (%)
# 3. Rolling Sortino Ratio (%)
# 4. Rolling Maximum Drawdown (%)

# %%
eps = 1e-8
def sharpe(returns, rfr=0):
    """ Given a set of returns, calculates naive (rfr=0) sharpe """
    # Clean list
    returns = [x for x in returns if str(x) != 'nan']
    if len(returns) < 10:
        return float('NaN')
    
    if isinstance(returns, list): 
        returns = np.array(returns)
    return (np.mean(returns - rfr + eps)) / np.std(returns - rfr + eps)


def sortino(returns, rfr=0):
    """ Given a set of returns, calculates naive (rfr=0) sortino """
    # Clean list
    returns = [x for x in returns if str(x) != 'nan']
    if len(returns) < 10:
        return float('NaN')
    
    if isinstance(returns, list): 
        returns = np.array(returns)
    return (np.mean(returns - rfr + eps)) / np.std([r for r in (returns - rfr + eps) if r < 0])


def max_drawdown(portfolio_value):
    """ Max drawdown. See https://www.investopedia.com/terms/m/maximum-drawdown-mdd.asp """
    # Clean list
    portfolio_value = [x for x in portfolio_value if str(x) != 'nan']
    
    mdd = 0
    peak = 0
    for i in list(range(len(portfolio_value))): 
        # Check if possible peak
        if(portfolio_value[i] > peak):
            # Max drawdown assuming this is the peak
            peak = portfolio_value[i]
            trough = min(portfolio_value[i:])
            if(peak > trough):
                d = abs((trough - peak) / peak)
                if(d > mdd):
                    mdd = d
    return mdd

# %%
model_name = full_model_names[0]
model_portfolio_values = portfolio_values_list[full_model_names.index(model_name)]
out_dates = extract_from_infos(info_list, 'date')
rolling_window = 100

# %% [markdown]
# ##### Rolling Average Daily Yield

# %%
roll_ady_df = pd.DataFrame()
roll_ady_df["Date"] = out_dates
roll_ady_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Average Daily Yield (%) (Window = {})'.format(rolling_window))
plt.ylabel('Average Daily Yield (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_ady_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(olps_portfolio_values_list[i]))
    roll_ady_df[olps_model_names[i]] = roll_ady_df['returns'].rolling(rolling_window).apply(np.mean, raw=True)
    plt.plot(roll_ady_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_ady_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(portfolio_values_list[i]))
    roll_ady_df[full_model_names[i]] = roll_ady_df['returns'].rolling(rolling_window).apply(np.mean, raw=True)
for name in model_names_best_insample:
    plt.plot(roll_ady_df[name].iloc[rolling_window:], label=name, 
             linewidth=2)

plt.xticks(np.arange(0, len(out_dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop column
roll_ady_df.drop('returns', axis=1, inplace=True)

# %% [markdown]
# #####  Rolling Sharpe Ratio

# %%
roll_sha_df = pd.DataFrame()
roll_sha_df["Date"] = out_dates
roll_sha_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Sharpe Ratio (%) (Window = {})'.format(rolling_window))
plt.ylabel('Sharpe Ratio (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_sha_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(olps_portfolio_values_list[i]))
    roll_sha_df[olps_model_names[i]] = roll_sha_df['returns'].rolling(rolling_window).apply(sharpe, raw=True)
    plt.plot(roll_sha_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_sha_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(portfolio_values_list[i]))
    roll_sha_df[full_model_names[i]] = roll_sha_df['returns'].rolling(rolling_window).apply(sharpe, raw=True)
for name in model_names_best_insample:
    plt.plot(roll_sha_df[name].iloc[rolling_window:], label=name, 
             linewidth=2)

plt.xticks(np.arange(0, len(out_dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop column
roll_sha_df.drop('returns', axis=1, inplace=True)

# %% [markdown]
# ##### Rolling Sortino Ratio

# %%
roll_sor_df = pd.DataFrame()
roll_sor_df["Date"] = out_dates
roll_sor_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Sortino Ratio (%) (Window = {})'.format(rolling_window))
plt.ylabel('Sortino Ratio (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_sor_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(olps_portfolio_values_list[i]))
    roll_sor_df[olps_model_names[i]] = roll_sor_df['returns'].rolling(rolling_window).apply(sortino, raw=True)
    plt.plot(roll_sor_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_sor_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(portfolio_values_list[i]))
    roll_sor_df[full_model_names[i]] = roll_sor_df['returns'].rolling(rolling_window).apply(sortino, raw=True)
for name in model_names_best_insample:
    plt.plot(roll_sor_df[name].iloc[rolling_window:], label=name, 
             linewidth=2)

plt.xticks(np.arange(0, len(out_dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop Column
roll_sor_df.drop('returns', axis=1, inplace=True)

# %% [markdown]
# ##### Rolling Maximum Drawdown

# %%
roll_mdd_df = pd.DataFrame()
roll_mdd_df["Date"] = out_dates
roll_mdd_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Maximum Drawdown (%) (Window = {})'.format(rolling_window))
plt.ylabel('Maximum Drawdown (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_mdd_df['portfolio'] =  olps_portfolio_values_list[i]
    roll_mdd_df[olps_model_names[i]] = roll_mdd_df['portfolio'].rolling(rolling_window).apply(max_drawdown, raw=True)
    plt.plot(roll_mdd_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_mdd_df['portfolio'] =  portfolio_values_list[i]
    roll_mdd_df[full_model_names[i]] = roll_mdd_df['portfolio'].rolling(rolling_window).apply(max_drawdown, raw=True)
for name in model_names_best_insample:
    plt.plot(roll_mdd_df[name].iloc[rolling_window:], label=name, 
             linewidth=2)

plt.xticks(np.arange(0, len(out_dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop Column
roll_mdd_df.drop('portfolio', axis=1, inplace=True)

# %%
# Average Daily Yield (%) 	Sharpe Ratio (%) 	Sortino Ratio (%) 	Maximum Drawdown (%)
# Mean and Standard deviation
temp = roll_ady_df.mean(axis = 0, skipna = True)
ady = ((temp-temp.min())/(temp.max()-temp.min())).tolist()
ady.insert(0, "Average Daily Yield")

temp = roll_sha_df.mean(axis = 0, skipna = True)
sha = ((temp-temp.min())/(temp.max()-temp.min())).tolist()
sha.insert(0, "Sharpe Ratio")

temp = roll_sor_df.mean(axis = 0, skipna = True)
sor = ((temp-temp.min())/(temp.max()-temp.min())).tolist()
sor.insert(0, "Sortino Ratio")

temp = roll_mdd_df.mean(axis = 0, skipna = True)
mdd = (1 - (temp-temp.min())/(temp.max()-temp.min())).tolist()
mdd.insert(0, "Maximum Drawdown (inverted)")

_results_df = pd.DataFrame([ady, sha, sor, mdd], columns=["Evaluation Criteria"] + roll_ady_df.columns.tolist())

_results_df.set_index('Evaluation Criteria', inplace=True)
_results_df

# %%
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Window Summary (Window = {})'.format(rolling_window))
plt.ylabel('Normalised Mean Values')
plt.xlabel('Evaluation Criteria')

# OLPS
for i in range(len(olps_model_names)):
    plt.plot(_results_df[olps_model_names[i]], label=olps_model_names[i], 
             linewidth=2.5, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    plt.plot(_results_df[full_model_names[i]], label=full_model_names[i], 
             linewidth=3)

plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %% [markdown]
# ##### Statistical summary via T-test

# %%
from scipy.stats import ttest_ind_from_stats

# %%
# All OLPS vs TD3-14-lstm-rmr_pred
n = len(roll_ady_df)
our_model = 'nyse_n_TD3_window_3_predictor_lstm'
print("{} vs... t-tests".format(our_model))

# %%
# Average Daily Yield (%)
mean = roll_ady_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_ady_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_ady_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

ady_tstat_list = ['ADY_tstat']
ady_pvalue_list = ['ADY_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    ady_tstat_list.append(tstat)
    ady_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

# %%
# Sharpe Ratio (%)
mean = roll_sha_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_sha_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_sha_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

sha_tstat_list = ['SHA_tstat']
sha_pvalue_list = ['SHA_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    sha_tstat_list.append(tstat)
    sha_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

# %%
# Sortino Ratio (%)
mean = roll_sor_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_sor_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_sor_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

sor_tstat_list = ['SOR_tstat']
sor_pvalue_list = ['SOR_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    sor_tstat_list.append(tstat)
    sor_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

# %%
# Maximum Drawdown (%)
mean = roll_mdd_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_mdd_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_mdd_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

mdd_tstat_list = ['MDD_tstat']
mdd_pvalue_list = ['MDD_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    mdd_tstat_list.append(tstat)
    mdd_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat < 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

# %%
stat_df = pd.DataFrame([ady_tstat_list, ady_pvalue_list, 
                       sha_tstat_list, sha_pvalue_list, 
                       sor_tstat_list, sor_pvalue_list, 
                       mdd_tstat_list, mdd_pvalue_list], columns=['value']+olps_model_names)
stat_df.set_index('value', inplace=True)
stat_df

# %% [markdown]
# ---------
# ## Statistical Test between two

# %%
td3_model = 'nyse_n_TD3_window_14_predictor_lstm'
ddpg_model = 'nyse_n_DDPG_window_7_predictor_lstm'

# %%
# Average Daily Yield (%)
mean = roll_ady_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_ady_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_ady_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

ady_tstat_list = ['ADY_tstat']
ady_pvalue_list = ['ADY_pvalue']


tstat, pvalue = ttest_ind_from_stats(_results_df[td3_model]['mean'], _results_df[td3_model]['std'], n, 
                                     _results_df[ddpg_model]['mean'], _results_df[ddpg_model]['std'], n)
ady_tstat_list.append(tstat)
ady_pvalue_list.append(pvalue)

print("{} | tstat = {} | pvalue = {}".format(ddpg_model, tstat, pvalue))
if(tstat > 0):
    print("Win")
else:
    print("Lose")
print("-----------------------------------------------------------------")

# %%
# Sharpe Ratio (%)
mean = roll_sha_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_sha_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_sha_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

sha_tstat_list = ['SHA_tstat']
sha_pvalue_list = ['SHA_pvalue']

tstat, pvalue = ttest_ind_from_stats(_results_df[td3_model]['mean'], _results_df[td3_model]['std'], n, 
                                     _results_df[ddpg_model]['mean'], _results_df[ddpg_model]['std'], n)
sha_tstat_list.append(tstat)
sha_pvalue_list.append(pvalue)

print("{} | tstat = {} | pvalue = {}".format(ddpg_model, tstat, pvalue))
if(tstat > 0):
    print("Win")
else:
    print("Lose")
print("-----------------------------------------------------------------")

# %%
# Sortino Ratio (%)
mean = roll_sor_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_sor_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_sor_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

sor_tstat_list = ['SOR_tstat']
sor_pvalue_list = ['SOR_pvalue']

tstat, pvalue = ttest_ind_from_stats(_results_df[td3_model]['mean'], _results_df[td3_model]['std'], n, 
                                     _results_df[ddpg_model]['mean'], _results_df[ddpg_model]['std'], n)
sor_tstat_list.append(tstat)
sor_pvalue_list.append(pvalue)

print("{} | tstat = {} | pvalue = {}".format(ddpg_model, tstat, pvalue))
if(tstat > 0):
    print("Win")
else:
    print("Lose")
print("-----------------------------------------------------------------")

# %%
# Maximum Drawdown (%)
mean = roll_mdd_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_mdd_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_mdd_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

mdd_tstat_list = ['MDD_tstat']
mdd_pvalue_list = ['MDD_pvalue']

tstat, pvalue = ttest_ind_from_stats(_results_df[td3_model]['mean'], _results_df[td3_model]['std'], n, 
                                     _results_df[ddpg_model]['mean'], _results_df[ddpg_model]['std'], n)
mdd_tstat_list.append(tstat)
mdd_pvalue_list.append(pvalue)

print("{} | tstat = {} | pvalue = {}".format(ddpg_model, tstat, pvalue))
if(tstat < 0):
    print("Win")
else:
    print("Lose")
print("-----------------------------------------------------------------")

# %%
stat_df = pd.DataFrame([ady_tstat_list, ady_pvalue_list, 
                       sha_tstat_list, sha_pvalue_list, 
                       sor_tstat_list, sor_pvalue_list, 
                       mdd_tstat_list, mdd_pvalue_list], columns=['value', ddpg_model])
stat_df.set_index('value', inplace=True)
stat_df
