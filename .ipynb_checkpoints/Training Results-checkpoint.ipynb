# %% [markdown]
# ### Training Results
# The training results are saved in csv format in the 'Reward_Data' folder.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'Reward_Data'

# %%
# List all files in Reward_Data folder
files = sorted(os.listdir(path))
names = []

for f in files:
    name = f[(f.rfind('-')+1):-11]
    names.append(name)
    print('{}: {}'.format(name,f))
# Out:
# nyse_n_DDPG_lstm_window_11_batch_norm:run-nyse_n_DDPG_lstm_window_11_batch_norm-tag-nyse_n_DDPG_lstm_window_11_batch_norm_Reward.csv
# nyse_n_DDPG_lstm_window_14_batch_norm:run-nyse_n_DDPG_lstm_window_14_batch_norm-tag-nyse_n_DDPG_lstm_window_14_batch_norm_Reward.csv
# nyse_n_DDPG_lstm_window_3_batch_norm:run-nyse_n_DDPG_lstm_window_3_batch_norm-tag-nyse_n_DDPG_lstm_window_3_batch_norm_Reward.csv
# nyse_n_DDPG_lstm_window_7_batch_norm:run-nyse_n_DDPG_lstm_window_7_batch_norm-tag-nyse_n_DDPG_lstm_window_7_batch_norm_Reward.csv
# nyse_n_TD3_lstm_window_11_batch_norm:run-nyse_n_TD3_lstm_window_11_batch_norm-tag-nyse_n_TD3_lstm_window_11_batch_norm_Reward.csv
# nyse_n_TD3_lstm_window_14_batch_norm:run-nyse_n_TD3_lstm_window_14_batch_norm-tag-nyse_n_TD3_lstm_window_14_batch_norm_Reward.csv
# nyse_n_TD3_lstm_window_3_batch_norm:run-nyse_n_TD3_lstm_window_3_batch_norm-tag-nyse_n_TD3_lstm_window_3_batch_norm_Reward.csv
# nyse_n_TD3_lstm_window_7_batch_norm:run-nyse_n_TD3_lstm_window_7_batch_norm-tag-nyse_n_TD3_lstm_window_7_batch_norm_Reward.csv

# %%
def movingaverage(interval, window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'same')

# %%
# Create a dictionary for each of these
d = {}

for i in range(len(files)):
    d[names[i]] = pd.read_csv('Reward_Data/{}'.format(files[i])).drop(['Wall time'], axis=1)
    #d[names[i]]['MA_10'] = movingaverage(d[names[i]]['Value'], 10)
    d[names[i]]['MA_10'] = d[names[i]]['Value'].rolling(window=10).mean()

# %%
d['nyse_n_DDPG_lstm_window_11_batch_norm'].head()
# Out:
#    Step     Value  MA_10
# 0     0  0.263030    NaN
# 1     1  0.475111    NaN
# 2     2  0.263170    NaN
# 3     3  0.014679    NaN
# 4     4  0.527215    NaN

# %%
# Lets plot these that have to do with nyse_n
names_for_plot = []
for n in names:
    if 'nyse_n' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    plt.plot(d[names_for_plot[i]]['MA_10'], label=names_for_plot[i])
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# Lets plot these that have to do with nyse_n
names_for_plot = []
for n in names:
    if 'DDPG' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All DDPG NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    plt.plot(d[names_for_plot[i]]['MA_10'], label=names_for_plot[i])
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
names_for_plot = []
for n in names:
    if 'TD3' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All TD3 NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    plt.plot(d[names_for_plot[i]]['MA_10'], label=names_for_plot[i])
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ## By Window

# %%
names_for_plot = []
for n in names:
    if 'window_3' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All window_3 NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    #plt.plot(d[names_for_plot[i]]['Value'], label=names_for_plot[i])
    plt.plot(d[names_for_plot[i]]['MA_10'], label='{}_MA(10)'.format(names_for_plot[i]))
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
names_for_plot = []
for n in names:
    if 'window_7' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All window_7 NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    #plt.plot(d[names_for_plot[i]]['Value'], label=names_for_plot[i])
    plt.plot(d[names_for_plot[i]]['MA_10'], label='{}_MA(10)'.format(names_for_plot[i]))
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
names_for_plot = []
for n in names:
    if 'window_11' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All window_11 NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    #plt.plot(d[names_for_plot[i]]['Value'], label=names_for_plot[i])
    plt.plot(d[names_for_plot[i]]['MA_10'], label='{}_MA(10)'.format(names_for_plot[i]))
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
names_for_plot = []
for n in names:
    if 'window_14' in n:
        names_for_plot.append(n)
# Steps
steps = d[names_for_plot[0]]['Step']
# Plot
log_y = False
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Reward Values (LOG Y)')
    plt.ylabel('Reward Value (LOG Y)')
else:
    plt.title('All window_14 NYSE(N) Reward Values')
    plt.ylabel('Reward Value')
plt.xlabel('Steps')
for i in range(len(names_for_plot)):
    #plt.plot(d[names_for_plot[i]]['Value'], label=names_for_plot[i])
    plt.plot(d[names_for_plot[i]]['MA_10'], label='{}_MA(10)'.format(names_for_plot[i]))
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(steps), 50))
plt.xticks(rotation=90)
plt.legend()
plt.show()
