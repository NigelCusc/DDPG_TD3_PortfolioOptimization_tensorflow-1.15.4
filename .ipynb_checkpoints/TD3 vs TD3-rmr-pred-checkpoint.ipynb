# %%
# IMPORTS
import os
import numpy as np
from utils.data import read_stock_history, normalize
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import seaborn as sns
import tensorflow as tf
from model.ddpg.actor import ActorNetwork
from model.ddpg.critic import CriticNetwork
from model.ddpg.ddpg import DDPG
from model.ornstein_uhlenbeck import OrnsteinUhlenbeckActionNoise
from model.td3.actor import TD3ActorNetwork
from model.td3.critic import TD3CriticNetwork
from model.td3.td3 import TD3
from stock_trading import Generate_technical_indicators, StockActor, StockCritic, TD3StockActor, TD3StockCritic, obs_normalizer, get_model_path, get_result_path, test_model, get_variable_scope, test_model_multiple
from environment.portfolio import PortfolioEnv, MultiActionPortfolioEnv, max_drawdown, sharpe, sortino, create_close_dataframe, convert_prices
import numpy as np
import tflearn
from stock_trading import test_portfolio_selection, test_portfolio_selection_multiple, plot_weights, plot_portfolio_values, results_table, results_table_row, returns_from_cumulative, returns_from_cumulative

from technical_indicators.technical_indicators import full_rmr_moving_average, olmar_moving_average

tf.__version__
print("Imports Complete")
# Out:
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Imports Complete

# %%
# common settings
batch_size = 64
action_bound = 1.
tau = 1e-3

models = []
model_names = []
framework_lst = ['TD3']
window_length_lst = [14]
maximum_window = max(window_length_lst)
predictor_type_lst = ['lstm']
use_batch_norm = True
log_return = True
load_technical_indicators = True

# %%
# Stock History
dataset_name = 'nyse_n'
history, assets, date_list = read_stock_history(filepath='utils/datasets/{}.h5'.format(dataset_name))
history = history[:, :, :4]
nb_classes = len(history) + 1
print("Dataset: {}".format(dataset_name))
print("Assets: {}".format(assets))
print("Stock History Shape: {}".format(history.shape))
print("Full Stock History Date Range: {} -> {}".format(date_list[0], date_list[-1]))
# Out:
# Dataset: nyse_n
# Assets: ['ahp', 'alcoa', 'amer_brands', 'coke', 'comm_metals', 'dow_chem', 'Dupont', 'ford', 'ge', 'gm', 'hp', 'ibm', 'ingersoll', 'jnj', 'kimb-clark', 'kin_ark', 'Kodak', 'merck', 'mmm', 'morris', 'p_and_g', 'schlum', 'sher_will']
# Stock History Shape: (23, 6430, 2)
# Full Stock History Date Range: 02/01/1985 -> 30/06/2010

# %%
full_length = len(date_list)
train_test_ratio = 6/7
train_start_date = date_list[maximum_window]
train_end_date = date_list[(int)(full_length * train_test_ratio)-1]
test_start_date = date_list[(int)(full_length * train_test_ratio)]
test_end_date = date_list[full_length-2]
print("Training Date Range: {} -> {} ({} Steps)".format(train_start_date, train_end_date, 
                                                    (int)(date_list.index(train_end_date) - date_list.index(train_start_date))))
print("Testing Date Range: {} -> {} ({} Steps)".format(test_start_date, test_end_date, 
                                                    (int)(date_list.index(test_end_date) - date_list.index(test_start_date))))
# Out:
# Training Date Range: 22/01/1985 -> 02/11/2006 (5496 Steps)
# Testing Date Range: 03/11/2006 -> 29/06/2010 (917 Steps)

# %%
# Generate Technical Indicators
def GenerateTechnicalIndicators(window_length, debug = False):
    if debug:
        print('history.shape: {}'.format(history.shape))

    # Check if just close is fed or full dataset
    if history.shape[2] == 4:
        # Get Close
        history_close = history[:, :, 3]
    elif history.shape[2] == 2:
        # Assume the one sent is the close price
        history_close = history[:, :, 1]

    if debug:
        print('history_close.shape: {}'.format(history_close.shape))

    # Add Technical Indicators to be included in state
    technical_indicator_history = []

    # Close Price DataFrame for on-line Portfolio Selection
    temp_close_df = create_close_dataframe(history, assets, date_list)
    temp_close_df = convert_prices(temp_close_df, 'raw', True)    
    if debug:
        print('temp_close_df.shape: {}'.format(temp_close_df.shape))

    rmr_moving_average_df = full_rmr_moving_average(temp_close_df, window_length)
    for i in range(len(assets)):
        # Create List
        ti = []
        #ti.append([olmar_moving_average(temp_close_df[assets[i]], window_length)]) # Based on OLMAR
        ti.append([rmr_moving_average_df[assets[i]]]) # Based on RMR

        # Turn to Array
        ti = np.vstack(ti)

        ti_reshaped = []
        for j in range(temp_close_df.shape[0]):
            ti_reshaped.append(ti[:, j])   

        technical_indicator_history.append(ti_reshaped)

    technical_indicator_history = np.array(technical_indicator_history)    
    if debug:
        print('technical_indicators.shape: {}'.format(technical_indicator_history.shape)) 
    
    ti_dict[window_length] = technical_indicator_history
    
    return technical_indicator_history

# %%
if load_technical_indicators:
    # Load Technical Indicators dataset
    ti_dict = np.load('technical_indicators/dictionaries/ti_dict-{}-rmr.npy'.format(dataset_name),allow_pickle='TRUE').item()
else:
    ti_dict = {}
    for window_length in window_length_lst:
        technical_indicator_history = GenerateTechnicalIndicators(window_length)
        ti_dict[window_length] = technical_indicator_history
    np.save('technical_indicators/dictionaries/ti_dict-{}-rmr.npy'.format(dataset_name), ti_dict)

# %%
# WITHOUT TECHNICAL INDICATORS
# instantiate environment
for framework in framework_lst:
    for window_length in window_length_lst:
        for predictor_type in predictor_type_lst:
            name = '{}_{}_window_{}_predictor_{}'.format(dataset_name, framework, window_length, predictor_type)
            model_names.append(name)
            tf.reset_default_graph()
            sess = tf.Session()
            tflearn.config.init_training_mode()
            action_dim = [nb_classes]
            state_dim = [nb_classes, window_length]
                
            variable_scope = get_variable_scope(dataset_name, framework, window_length, predictor_type, 
                                                use_batch_norm, False)

            with tf.variable_scope(variable_scope):
                
                if(framework == 'DDPG'):
                    actor = StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, 
                                       predictor_type, use_batch_norm)
                    critic = StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                             learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(), 
                             predictor_type=predictor_type, use_batch_norm=use_batch_norm)
                    actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

                    model_save_path = get_model_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, False)
                    summary_path = get_result_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, False)

                    ddpg_model = DDPG(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer,
                                      log_return=log_return, config_file='config/stock.json', 
                                      model_save_path=model_save_path, summary_path=summary_path)
                    ddpg_model.initialize(load_weights=True, verbose=True)
                    models.append(ddpg_model)
                    
                elif(framework == 'TD3'):
                    actor = TD3StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, 
                                          predictor_type, use_batch_norm)
                    critic = TD3StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                             learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(),
                             predictor_type=predictor_type, use_batch_norm=use_batch_norm,
                               inp_actions=actor.scaled_out)
                    actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

                    model_save_path = get_model_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, False)
                    summary_path = get_result_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, False)

                    td3_model = TD3(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer, 
                                    log_return=log_return, config_file='config/stock.json', 
                                    model_save_path=model_save_path, summary_path=summary_path)
                    td3_model.initialize(load_weights=True, verbose=True)
                    models.append(td3_model)
# Out:
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/layers/core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/layers/recurrent.py:69: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/layers/recurrent.py:553: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/initializations.py:174: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/tflearn/initializations.py:75: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/actor.py:45: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/actor.py:63: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/actor.py:66: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:20: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:25: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:69: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/nigel/Desktop/DDPG_TD3_PortfolioOptimization_tensorflow-1.15.4/model/td3/td3.py:71: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from weights/nyse_n/TD3/lstm/window_14/batch_norm/checkpoint.ckpt
# Loading is_training:0 from checkpoint. Name: is_training
# Loading nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_2/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_3/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/beta1_power:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/beta1_power
# Loading nyse_n_TD3_lstm_window_14_batch_norm/beta2_power:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/beta2_power
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/target_critic/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/target_critic/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm/beta1_power_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/beta1_power_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/beta2_power_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/beta2_power_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_1/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_2/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_3/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_4/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/main_critic/FullyConnected_5/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/Variable:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/Variable
# Loading nyse_n_TD3_lstm_window_14_batch_norm/Variable_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/Variable_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm/beta1_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/beta1_power_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/beta2_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/beta2_power_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/nyse_n_TD3_lstm_window_14_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected/b/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/beta/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization/gamma/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_1/b/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/beta/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/BatchNormalization_1/gamma/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm/nyse_n_TD3_lstm_window_14_batch_norm/FullyConnected_2/b/Adam_3

# %%
# With Technical Indicators
# instantiate environment
for framework in framework_lst:
    for window_length in window_length_lst:
        for predictor_type in predictor_type_lst:
            name = '{}_{}_window_{}_predictor_{}_{}'.format(dataset_name, framework, window_length, predictor_type, "rmr-pred")
            model_names.append(name)
            tf.reset_default_graph()
            sess = tf.Session()
            tflearn.config.init_training_mode()
            action_dim = [nb_classes]
            technical_indicator_history = ti_dict[window_length]
            state_dim = [nb_classes, window_length+technical_indicator_history.shape[2]]

            variable_scope = get_variable_scope(dataset_name, framework, window_length, predictor_type, 
                                                use_batch_norm, True)

            with tf.variable_scope(variable_scope):

                if(framework == 'DDPG'):
                    actor = StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, 
                                       predictor_type, use_batch_norm)
                    critic = StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                             learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(), 
                             predictor_type=predictor_type, use_batch_norm=use_batch_norm)
                    actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

                    model_save_path = get_model_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, True)
                    summary_path = get_result_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, True)

                    ddpg_model = DDPG(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer,
                                      log_return=log_return, config_file='config/stock.json', 
                                      model_save_path=model_save_path, summary_path=summary_path)
                    ddpg_model.initialize(load_weights=True, verbose=True)
                    models.append(ddpg_model)

                elif(framework == 'TD3'):
                    actor = TD3StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, 
                                          predictor_type, use_batch_norm)
                    critic = TD3StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                             learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(),
                             predictor_type=predictor_type, use_batch_norm=use_batch_norm,
                               inp_actions=actor.scaled_out)
                    actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

                    model_save_path = get_model_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, True)
                    summary_path = get_result_path(dataset_name, framework, window_length, predictor_type, use_batch_norm, True)

                    td3_model = TD3(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer, 
                                    log_return=log_return, config_file='config/stock.json', 
                                    model_save_path=model_save_path, summary_path=summary_path)
                    td3_model.initialize(load_weights=True, verbose=True)
                    models.append(td3_model)
# Out:
# INFO:tensorflow:Restoring parameters from weights/nyse_n/TD3/lstm/window_14/batch_norm/technical_indicators/checkpoint.ckpt
# Loading is_training:0 from checkpoint. Name: is_training
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_2/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_3/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_1/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_1/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_1/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_1/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_2/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_2/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_2/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_2/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_3/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_3/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_3/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_3/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_4/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_4/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_4/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_4/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/beta:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/beta
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/gamma:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/gamma
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_mean:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_mean
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_variance:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/BatchNormalization_1/moving_variance
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_5/W:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_5/W
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_5/b:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/target_critic/FullyConnected_5/b
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_1/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_2/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/LSTM_1/BasicLSTMCell/Linear/Bias/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_3/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_4/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/beta/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/BatchNormalization_1/gamma/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/W/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/main_critic/FullyConnected_5/b/Adam_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable_1:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/Variable_1
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta1_power_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/beta2_power_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Matrix/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/LSTM/BasicLSTMCell/Linear/Bias/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected/b/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/beta/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization/gamma/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_1/b/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/beta/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/BatchNormalization_1/gamma/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/W/Adam_3
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_2:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_2
# Loading nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_3:0 from checkpoint. Name: nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/nyse_n_TD3_lstm_window_14_batch_norm_technical_indicators/FullyConnected_2/b/Adam_3

# %%
model_names
# Out:
# ['nyse_n_TD3_window_14_predictor_lstm',
#  'nyse_n_TD3_window_14_predictor_lstm_rmr-pred']

# %% [markdown]
# #### IN SAMPLE

# %%
# Compiled Results
full_model_names = []
full_models = []
full_observations_list = []
full_info_list = []
full_action_list = []
full_df_performance = []
portfolio_values_list = [] 

for window_length in window_length_lst:
    model_names_subset = []
    models_subset = []
    for i in range(len(model_names)):
        if 'window_{}'.format(window_length) in model_names[i]:
            if 'rmr-pred' in model_names[i]:
                ti_model_name = model_names[i]
                ti_model = models[i]
            else:
                model_name = model_names[i]
                model = models[i]
            
    # no technical indicators ------------------------
    print("Model: {}".format(model_name))
    env = PortfolioEnv(history, assets, date_list, start_date=train_start_date, 
                              end_date=train_end_date, window_length=window_length)

    _, observations, info_list, actions, _, _, portfolio_values, _ = test_model(env, model)
    
    # Add to results
    full_model_names.append(model_name)
    full_models.append(model)    
    full_observations_list.append(observations)    
    full_info_list.append(info_list)    
    full_action_list.append(actions)  
    portfolio_values_list.append(portfolio_values)
        
    # technical indicators ---------------------------
    print("Model: {}".format(ti_model_name))
    env = PortfolioEnv(history, assets, date_list, start_date=train_start_date, 
                              end_date=train_end_date, window_length=window_length, 
                                  technical_indicators_flag=True, 
                                  technical_indicator_history=ti_dict[window_length])
    
    _, observations, info_list, actions, _, _, portfolio_values, _ = test_model(env, ti_model)
    
    # Add to results
    full_model_names.append(ti_model_name)
    full_models.append(ti_model)    
    full_observations_list.append(observations)    
    full_info_list.append(info_list)    
    full_action_list.append(actions)  
    portfolio_values_list.append(portfolio_values)
# Out:
# Model: nyse_n_TD3_window_14_predictor_lstm
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Model: nyse_n_TD3_window_14_predictor_lstm_rmr-pred
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# Set Up Environment
env = PortfolioEnv(history, assets, date_list, start_date=train_start_date, 
                              end_date=train_end_date, window_length=3, olps=True)

olps_model_names = ['CRP', 'BCRP', 'OLMAR', 'PAMR', 'RMR', 'WMAMR', 'EG', 'ONS', 'UP']
in_observations_list, in_olps_portfolio_values_list, in_weights_list, in_dates = test_portfolio_selection_multiple(env, 
                                                                                                olps_model_names)
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# =========CRP=========
# len(weights_array): 6430
# =========BCRP=========
# len(weights_array): 5497
# =========OLMAR=========
# len(weights_array): 5497
# =========PAMR=========
# len(weights_array): 5497
# =========RMR=========
# len(weights_array): 5497
# =========WMAMR=========
# len(weights_array): 5497
# =========EG=========
# len(weights_array): 5497
# =========ONS=========
# len(weights_array): 5497
# =========UP=========
# len(weights_array): 5497

# %% [markdown]
# #### OUT OF SAMPLE

# %%
# Compiled Results
full_model_names = []
full_models = []
full_observations_list = []
full_info_list = []
full_action_list = []
full_df_performance = []
portfolio_values_list = [] 

for window_length in window_length_lst:
    model_names_subset = []
    models_subset = []
    for i in range(len(model_names)):
        if 'window_{}'.format(window_length) in model_names[i]:
            if 'rmr-pred' in model_names[i]:
                ti_model_name = model_names[i]
                ti_model = models[i]
            else:
                model_name = model_names[i]
                model = models[i]
                
    # no technical indicators ------------------------
    env = PortfolioEnv(history, assets, date_list, start_date=test_start_date, 
                              end_date=test_end_date, window_length=window_length)

    dates, observations, info_list, actions, _, _, portfolio_values, market_values = test_model(env, model)
    
    # Add to results
    full_model_names.append(model_name)
    full_models.append(model)    
    full_observations_list.append(observations)    
    full_info_list.append(info_list)    
    full_action_list.append(actions)  
    portfolio_values_list.append(portfolio_values)
        
    # technical indicators ---------------------------
    env = PortfolioEnv(history, assets, date_list, start_date=test_start_date, 
                              end_date=test_end_date, window_length=window_length, 
                                  technical_indicators_flag=True, 
                                  technical_indicator_history=ti_dict[window_length])
    
    dates, observations, info_list, actions, _, _, portfolio_values, market_values = test_model(env, ti_model)
    
    # Add to results
    full_model_names.append(ti_model_name)
    full_models.append(ti_model)    
    full_observations_list.append(observations)    
    full_info_list.append(info_list)    
    full_action_list.append(actions)  
    portfolio_values_list.append(portfolio_values)
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# #### Plot

# %%
log_y = False
df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')
for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
    plt.plot(df[full_model_names[i]], label=full_model_names[i])
df['market_value'] = market_values
plt.plot(df['market_value'], label='market_value')
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
log_y = True
df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')
for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
    plt.plot(df[full_model_names[i]], label=full_model_names[i])
df['market_value'] = market_values
plt.plot(df['market_value'], label='market_value')
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.25, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
# RESULT
df = pd.DataFrame(columns=['Portfolio', 'Average Daily Yield (%)', 'Sharpe Ratio (%)', 'Sortino Ratio (%)', 'Maximum Drawdown (%)',
                           'Final Portfolio Value'])
for i in range(len(full_model_names)):
    df = results_table_row(df, full_model_names[i],
                           returns_from_cumulative(portfolio_values_list[i]),
                           portfolio_values_list[i])
# Market
df = results_table_row(df, 'market_value',
                           returns_from_cumulative(market_values),
                           market_values)
df
# Out:
#                                       Portfolio  Average Daily Yield (%)  \
# 0           nyse_n_TD3_window_14_predictor_lstm                   0.0591
# 1  nyse_n_TD3_window_14_predictor_lstm_rmr-pred                   0.1511
# 2                                  market_value                   0.0184
#
#    Sharpe Ratio (%)  Sortino Ratio (%)  Maximum Drawdown (%)  \
# 0            2.3820             3.2996               52.1218
# 1            3.5843             5.2605               79.8014
# 2            0.9736             1.2451               62.6889
#
#    Final Portfolio Value
# 0                  1.305
# 1                  1.838
# 2                  1.005

# %% [markdown]
# #### Compare with online-portfolio selection

# %%
# Set Up Environment
env = PortfolioEnv(history, assets, date_list, start_date=test_start_date, 
                              end_date=test_end_date, window_length=3, olps=True)

olps_model_names = ['CRP', 'BCRP', 'OLMAR', 'PAMR', 'RMR', 'WMAMR', 'EG', 'ONS', 'UP']
observations_list, olps_portfolio_values_list, weights_list, dates = test_portfolio_selection_multiple(env, 
                                                                                                olps_model_names)
# Out:
# /home/nigel/anaconda3/envs/tensor_keras_portfolio/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# =========CRP=========
# len(weights_array): 6430
# =========BCRP=========
# len(weights_array): 918
# =========OLMAR=========
# len(weights_array): 918
# =========PAMR=========
# len(weights_array): 918
# =========RMR=========
# len(weights_array): 918
# =========WMAMR=========
# len(weights_array): 918
# =========EG=========
# len(weights_array): 918
# =========ONS=========
# len(weights_array): 918
# =========UP=========
# len(weights_array): 918

# %%
log_y = False
df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')
for i in range(len(olps_model_names)):
    df[olps_model_names[i]] = olps_portfolio_values_list[i]
    plt.plot(df[olps_model_names[i]], label=olps_model_names[i])
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.1, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
log_y = False

df = pd.DataFrame()
df["Date"] = dates
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
if log_y:
    plt.title('Portfolio Values (LOG Y)')
    plt.ylabel('Portfolio Value (LOG Y)')
else:
    plt.title('Portfolio Values')
    plt.ylabel('Portfolio Value')
plt.xlabel('Day')

for i in range(len(full_model_names)):
    df[full_model_names[i]] = portfolio_values_list[i]
    plt.plot(df[full_model_names[i]], label=full_model_names[i],
         linewidth=2.5)

for i in range(len(olps_model_names)):
    df[olps_model_names[i]] = olps_portfolio_values_list[i]
    plt.plot(df[olps_model_names[i]], label=olps_model_names[i], linewidth=1, linestyle='dashed')
    
if log_y:
    plt.yscale('log')
plt.xticks(np.arange(0, len(dates), 100))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# %%
# RESULT
df = pd.DataFrame(columns=['Portfolio', 'Average Daily Yield (%)', 'Sharpe Ratio (%)', 'Sortino Ratio (%)', 'Maximum Drawdown (%)',
                           'Final Portfolio Value'])
for i in range(len(full_model_names)):
    df = results_table_row(df, full_model_names[i],
                           returns_from_cumulative(portfolio_values_list[i]),
                           portfolio_values_list[i])

for i in range(len(olps_model_names)):
    df = results_table_row(df, olps_model_names[i],
                           returns_from_cumulative(olps_portfolio_values_list[i]),
                           olps_portfolio_values_list[i])

df
# Out:
#                                        Portfolio  Average Daily Yield (%)  \
# 0            nyse_n_TD3_window_14_predictor_lstm                   0.0591
# 1   nyse_n_TD3_window_14_predictor_lstm_rmr-pred                   0.1511
# 2                                            CRP                   0.0145
# 3                                           BCRP                   0.1139
# 4                                          OLMAR                   0.2199
# 5                                           PAMR                   0.1815
# 6                                            RMR                   0.2103
# 7                                          WMAMR                   0.0236
# 8                                             EG                   0.0133
# 9                                            ONS                   0.0057
# 10                                            UP                   0.0145
#
#     Sharpe Ratio (%)  Sortino Ratio (%)  Maximum Drawdown (%)  \
# 0             2.3820             3.2996               52.1218
# 1             3.5843             5.2605               79.8014
# 2             0.7684             0.9817               63.2787
# 3             3.7366             5.8033               73.2078
# 4             3.4137             4.6782               91.4425
# 5             3.6662             5.0717               79.0335
# 6             3.2596             4.5271               91.6121
# 7             0.3772             0.4779               94.6415
# 8             0.7114             0.9070               63.1222
# 9             0.0757             0.0852               96.1809
# 10            0.7724             0.9904               63.0782
#
#     Final Portfolio Value
# 0                   1.305
# 1                   1.838
# 2                   0.970
# 3                   1.876
# 4                   1.206
# 5                   1.797
# 6                   1.104
# 7                   0.206
# 8                   0.962
# 9                   0.072
# 10                  0.971

# %% [markdown]
# ----------------
# ### Best Model vs. Benchmarks
# 1. Rolling Average Daily Yield (%)
# 2. Rolling Sharpe Ratio (%)
# 3. Rolling Sortino Ratio (%)
# 4. Rolling Maximum Drawdown (%)

# %%
eps = 1e-8
def sharpe(returns, rfr=0):
    """ Given a set of returns, calculates naive (rfr=0) sharpe """
    # Clean list
    returns = [x for x in returns if str(x) != 'nan']
    if len(returns) < 10:
        return float('NaN')
    
    if isinstance(returns, list): 
        returns = np.array(returns)
    result = (np.mean(returns - rfr + eps)) / np.std(returns - rfr + eps)
    return round(result*100, 4)

def sortino(returns, rfr=0):
    """ Given a set of returns, calculates naive (rfr=0) sortino """
    # Clean list
    returns = [x for x in returns if str(x) != 'nan']
    if len(returns) < 10:
        return float('NaN')
    
    if isinstance(returns, list): 
        returns = np.array(returns)
    result = (np.mean(returns - rfr + eps)) / np.std([r for r in (returns - rfr + eps) if r < 0])
    return round(result*100, 4)

def max_drawdown(portfolio_value):
    """ Max drawdown. See https://www.investopedia.com/terms/m/maximum-drawdown-mdd.asp """
    # Clean list
    portfolio_value = [x for x in portfolio_value if str(x) != 'nan']
    
    mdd = 0
    peak = 0
    for i in list(range(len(portfolio_value))): 
        # Check if possible peak
        if(portfolio_value[i] > peak):
            # Max drawdown assuming this is the peak
            peak = portfolio_value[i]
            trough = min(portfolio_value[i:])
            if(peak > trough):
                d = abs((trough - peak) / peak)
                if(d > mdd):
                    mdd = d
    return round(mdd*100, 4)

# %%
full_model_names
# Out:
# ['nyse_n_TD3_window_14_predictor_lstm',
#  'nyse_n_TD3_window_14_predictor_lstm_rmr-pred']

# %%
model_name = full_model_names[0]
model_portfolio_values = portfolio_values_list[full_model_names.index(model_name)]
rolling_window = 100

# %% [markdown]
# ### Rolling Average Daily Yield

# %%
roll_ady_df = pd.DataFrame()
roll_ady_df["Date"] = dates
roll_ady_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Average Daily Yield (%) (Window = {})'.format(rolling_window))
plt.ylabel('Average Daily Yield (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_ady_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(olps_portfolio_values_list[i]))
    roll_ady_df[olps_model_names[i]] = roll_ady_df['returns'].rolling(rolling_window).apply(np.mean, raw=True)
    plt.plot(roll_ady_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_ady_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(portfolio_values_list[i]))
    roll_ady_df[full_model_names[i]] = roll_ady_df['returns'].rolling(rolling_window).apply(np.mean, raw=True)
    plt.plot(roll_ady_df[full_model_names[i]].iloc[rolling_window:], label=full_model_names[i], 
             linewidth=2)

plt.xticks(np.arange(0, len(dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.30, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop column
roll_ady_df.drop('returns', axis=1, inplace=True)

# %% [markdown]
# ### Rolling Sharpe Ratio

# %%
roll_sha_df = pd.DataFrame()
roll_sha_df["Date"] = dates
roll_sha_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Sharpe Ratio (%) (Window = {})'.format(rolling_window))
plt.ylabel('Sharpe Ratio (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_sha_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(olps_portfolio_values_list[i]))
    roll_sha_df[olps_model_names[i]] = roll_sha_df['returns'].rolling(rolling_window).apply(sharpe, raw=True)
    plt.plot(roll_sha_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_sha_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(portfolio_values_list[i]))
    roll_sha_df[full_model_names[i]] = roll_sha_df['returns'].rolling(rolling_window).apply(sharpe, raw=True)
    plt.plot(roll_sha_df[full_model_names[i]].iloc[rolling_window:], label=full_model_names[i], 
             linewidth=2)

plt.xticks(np.arange(0, len(dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.30, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop column
roll_sha_df.drop('returns', axis=1, inplace=True)

# %% [markdown]
# ### Rolling Sortino Ratio

# %%
roll_sor_df = pd.DataFrame()
roll_sor_df["Date"] = dates
roll_sor_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Sortino Ratio (%) (Window = {})'.format(rolling_window))
plt.ylabel('Sortino Ratio (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_sor_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(olps_portfolio_values_list[i]))
    roll_sor_df[olps_model_names[i]] = roll_sor_df['returns'].rolling(rolling_window).apply(sortino, raw=True)
    plt.plot(roll_sor_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_sor_df['returns'] =  np.append(np.repeat(np.nan, 1), returns_from_cumulative(portfolio_values_list[i]))
    roll_sor_df[full_model_names[i]] = roll_sor_df['returns'].rolling(rolling_window).apply(sortino, raw=True)
    plt.plot(roll_sor_df[full_model_names[i]].iloc[rolling_window:], label=full_model_names[i], 
             linewidth=2)

plt.xticks(np.arange(0, len(dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop Column
roll_sor_df.drop('returns', axis=1, inplace=True)

# %% [markdown]
# ### Rolling Maximum Drawdown

# %%
roll_mdd_df = pd.DataFrame()
roll_mdd_df["Date"] = dates
roll_mdd_df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6), dpi=100)
plt.title('Rolling Maximum Drawdown (%) (Window = {})'.format(rolling_window))
plt.ylabel('Maximum Drawdown (%)')
plt.xlabel('Day')

# OLPS
for i in range(len(olps_model_names)):
    roll_mdd_df['portfolio'] =  olps_portfolio_values_list[i]
    roll_mdd_df[olps_model_names[i]] = roll_mdd_df['portfolio'].rolling(rolling_window).apply(max_drawdown, raw=True)
    plt.plot(roll_mdd_df[olps_model_names[i]].iloc[rolling_window:], label=olps_model_names[i], 
             linewidth=1, 
             linestyle='dashed')

# Our models
for i in range(len(full_model_names)):
    roll_mdd_df['portfolio'] =  portfolio_values_list[i]
    roll_mdd_df[full_model_names[i]] = roll_mdd_df['portfolio'].rolling(rolling_window).apply(max_drawdown, raw=True)
    plt.plot(roll_mdd_df[full_model_names[i]].iloc[rolling_window:], label=full_model_names[i], 
             linewidth=2)

plt.xticks(np.arange(0, len(dates), rolling_window))
plt.xticks(rotation=90)
plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1), shadow=True, ncol=1)
plt.grid(color='black', linestyle=':', linewidth=1)
plt.show()

# Drop Column
roll_mdd_df.drop('portfolio', axis=1, inplace=True)

# %% [markdown]
# ##### Statistical summary via T-test

# %%
from scipy.stats import ttest_ind_from_stats

# %%
# All OLPS vs TD3-14-lstm-rmr_pred
n = len(roll_ady_df)
our_model = 'nyse_n_TD3_window_14_predictor_lstm_rmr-pred'
print("{} vs... t-tests".format(our_model))
# Out:
# nyse_n_TD3_window_14_predictor_lstm_rmr-pred vs... t-tests

# %%
# Average Daily Yield (%)
mean = roll_ady_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_ady_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_ady_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

ady_tstat_list = ['ADY_tstat']
ady_pvalue_list = ['ADY_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    ady_tstat_list.append(tstat)
    ady_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

for model in full_model_names:
    stat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[model]['mean'], _results_df[model]['std'], n)
    ady_tstat_list.append(tstat)
    ady_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")
# Out:
# CRP | tstat = 9.698449748990257 | pvalue = 1.0074084095395517e-21
# Win
# -----------------------------------------------------------------
# BCRP | tstat = 2.4997103629851187 | pvalue = 0.012516252596007605
# Win
# -----------------------------------------------------------------
# OLMAR | tstat = -3.7105837369263868 | pvalue = 0.00021294454531681646
# Lose
# -----------------------------------------------------------------
# PAMR | tstat = -2.1306582354770103 | pvalue = 0.0332500150893285
# Lose
# -----------------------------------------------------------------
# RMR | tstat = -3.3163247056150515 | pvalue = 0.0009299049331760743
# Lose
# -----------------------------------------------------------------
# WMAMR | tstat = 4.609990002595455 | pvalue = 4.304880069031547e-06
# Win
# -----------------------------------------------------------------
# EG | tstat = 9.798561426419568 | pvalue = 3.945395662016653e-22
# Win
# -----------------------------------------------------------------
# ONS | tstat = 8.71416031459237 | pvalue = 6.423021747897095e-18
# Win
# -----------------------------------------------------------------
# UP | tstat = 9.684462187068677 | pvalue = 1.1476088821264971e-21
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm | tstat = 9.684462187068677 | pvalue = 2.0658410848724373e-10
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm_rmr-pred | tstat = 9.684462187068677 | pvalue = 1.0
# Win
# -----------------------------------------------------------------

# %%
# Sharpe Ratio (%)
mean = roll_sha_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_sha_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_sha_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

sha_tstat_list = ['SHA_tstat']
sha_pvalue_list = ['SHA_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    sha_tstat_list.append(tstat)
    sha_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

for model in full_model_names:
    stat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[model]['mean'], _results_df[model]['std'], n)
    sha_tstat_list.append(tstat)
    sha_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")
# Out:
# CRP | tstat = 4.69233132245353 | pvalue = 2.9010808446261607e-06
# Win
# -----------------------------------------------------------------
# BCRP | tstat = 0.9414845622663953 | pvalue = 0.34658058823784976
# Win
# -----------------------------------------------------------------
# OLMAR | tstat = 5.416422787094549 | pvalue = 6.882449808206391e-08
# Win
# -----------------------------------------------------------------
# PAMR | tstat = 2.2091164903194356 | pvalue = 0.027289744606333724
# Win
# -----------------------------------------------------------------
# RMR | tstat = 5.062709143296948 | pvalue = 4.5478856479406114e-07
# Win
# -----------------------------------------------------------------
# WMAMR | tstat = 7.959043608107631 | pvalue = 3.0097506616617958e-15
# Win
# -----------------------------------------------------------------
# EG | tstat = 4.760587151247966 | pvalue = 2.081650278968611e-06
# Win
# -----------------------------------------------------------------
# ONS | tstat = 9.611562586490932 | pvalue = 2.257097986459321e-21
# Win
# -----------------------------------------------------------------
# UP | tstat = 4.607035732042068 | pvalue = 4.365760147375401e-06
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm | tstat = 4.607035732042068 | pvalue = 2.511746751485215e-07
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm_rmr-pred | tstat = 4.607035732042068 | pvalue = 1.0
# Win
# -----------------------------------------------------------------

# %%
# Sortino Ratio (%)
mean = roll_sor_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_sor_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_sor_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

sor_tstat_list = ['SOR_tstat']
sor_pvalue_list = ['SOR_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    sor_tstat_list.append(tstat)
    sor_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

for model in full_model_names:
    stat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[model]['mean'], _results_df[model]['std'], n)
    sor_tstat_list.append(tstat)
    sor_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")
# Out:
# CRP | tstat = 9.736231516313692 | pvalue = 7.079375178888894e-22
# Win
# -----------------------------------------------------------------
# BCRP | tstat = 2.7042605775936828 | pvalue = 0.006908926355168086
# Win
# -----------------------------------------------------------------
# OLMAR | tstat = 2.4520426774083726 | pvalue = 0.014297420752209815
# Win
# -----------------------------------------------------------------
# PAMR | tstat = 2.5563660605665968 | pvalue = 0.010657122191220947
# Win
# -----------------------------------------------------------------
# RMR | tstat = 2.442690013406899 | pvalue = 0.014672056921219496
# Win
# -----------------------------------------------------------------
# WMAMR | tstat = 4.432439452567427 | pvalue = 9.868477179175525e-06
# Win
# -----------------------------------------------------------------
# EG | tstat = 9.86406053769446 | pvalue = 2.126861714358786e-22
# Win
# -----------------------------------------------------------------
# ONS | tstat = 13.695922560148174 | pvalue = 1.0071408427368668e-40
# Win
# -----------------------------------------------------------------
# UP | tstat = 9.678548349418866 | pvalue = 1.2125435616637764e-21
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm | tstat = 9.678548349418866 | pvalue = 6.332642365213635e-11
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm_rmr-pred | tstat = 9.678548349418866 | pvalue = 1.0
# Win
# -----------------------------------------------------------------

# %%
# Maximum Drawdown (%)
mean = roll_mdd_df.mean(axis = 0, skipna = True).tolist()
mean.insert(0, "mean")
std = roll_mdd_df.std(axis = 0, skipna = True).tolist()
std.insert(0, "std")
_results_df = pd.DataFrame([mean, std], columns=["Value"] + roll_mdd_df.columns.tolist())
_results_df.set_index('Value', inplace=True)

mdd_tstat_list = ['MDD_tstat']
mdd_pvalue_list = ['MDD_pvalue']

for olps_model in olps_model_names:
    tstat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[olps_model]['mean'], _results_df[olps_model]['std'], n)
    mdd_tstat_list.append(tstat)
    mdd_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(olps_model, tstat, pvalue))
    if(tstat < 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")

for model in full_model_names:
    stat, pvalue = ttest_ind_from_stats(_results_df[our_model]['mean'], _results_df[our_model]['std'], n, 
                                         _results_df[model]['mean'], _results_df[model]['std'], n)
    mdd_tstat_list.append(tstat)
    mdd_pvalue_list.append(pvalue)
    
    print("{} | tstat = {} | pvalue = {}".format(model, tstat, pvalue))
    if(tstat > 0):
        print("Win")
    else:
        print("Lose")
    print("-----------------------------------------------------------------")
# Out:
# CRP | tstat = 19.2642753185186 | pvalue = 1.850146798754897e-75
# Lose
# -----------------------------------------------------------------
# BCRP | tstat = 7.066782929270148 | pvalue = 2.2439380609983828e-12
# Lose
# -----------------------------------------------------------------
# OLMAR | tstat = -12.883098942600023 | pvalue = 2.0225908087537863e-36
# Win
# -----------------------------------------------------------------
# PAMR | tstat = -3.092019018231986 | pvalue = 0.002017934607471135
# Win
# -----------------------------------------------------------------
# RMR | tstat = -12.615447004186601 | pvalue = 4.736798317341618e-35
# Win
# -----------------------------------------------------------------
# WMAMR | tstat = -11.684218533247012 | pvalue = 1.7910423690392708e-30
# Win
# -----------------------------------------------------------------
# EG | tstat = 19.396193782815537 | pvalue = 2.2118046431126646e-76
# Lose
# -----------------------------------------------------------------
# ONS | tstat = -8.639498040885785 | pvalue = 1.2063997805765763e-17
# Win
# -----------------------------------------------------------------
# UP | tstat = 19.39845254838754 | pvalue = 2.1326328271132303e-76
# Lose
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm | tstat = 19.39845254838754 | pvalue = 3.149854986244291e-63
# Win
# -----------------------------------------------------------------
# nyse_n_TD3_window_14_predictor_lstm_rmr-pred | tstat = 19.39845254838754 | pvalue = 1.0
# Win
# -----------------------------------------------------------------

# %%
stat_df = pd.DataFrame([ady_tstat_list, ady_pvalue_list, 
                       sha_tstat_list, sha_pvalue_list, 
                       sor_tstat_list, sor_pvalue_list, 
                       mdd_tstat_list, mdd_pvalue_list], columns=['value']+olps_model_names+full_model_names)
stat_df.set_index('value', inplace=True)
stat_df
# Out:
#                      CRP          BCRP         OLMAR      PAMR           RMR  \
# value
# ADY_tstat   9.698450e+00  2.499710e+00 -3.710584e+00 -2.130658 -3.316325e+00
# ADY_pvalue  1.007408e-21  1.251625e-02  2.129445e-04  0.033250  9.299049e-04
# SHA_tstat   4.692331e+00  9.414846e-01  5.416423e+00  2.209116  5.062709e+00
# SHA_pvalue  2.901081e-06  3.465806e-01  6.882450e-08  0.027290  4.547886e-07
# SOR_tstat   9.736232e+00  2.704261e+00  2.452043e+00  2.556366  2.442690e+00
# SOR_pvalue  7.079375e-22  6.908926e-03  1.429742e-02  0.010657  1.467206e-02
# MDD_tstat   1.926428e+01  7.066783e+00 -1.288310e+01 -3.092019 -1.261545e+01
# MDD_pvalue  1.850147e-75  2.243938e-12  2.022591e-36  0.002018  4.736798e-35
#
#                    WMAMR            EG           ONS            UP  \
# value
# ADY_tstat   4.609990e+00  9.798561e+00  8.714160e+00  9.684462e+00
# ADY_pvalue  4.304880e-06  3.945396e-22  6.423022e-18  1.147609e-21
# SHA_tstat   7.959044e+00  4.760587e+00  9.611563e+00  4.607036e+00
# SHA_pvalue  3.009751e-15  2.081650e-06  2.257098e-21  4.365760e-06
# SOR_tstat   4.432439e+00  9.864061e+00  1.369592e+01  9.678548e+00
# SOR_pvalue  9.868477e-06  2.126862e-22  1.007141e-40  1.212544e-21
# MDD_tstat  -1.168422e+01  1.939619e+01 -8.639498e+00  1.939845e+01
# MDD_pvalue  1.791042e-30  2.211805e-76  1.206400e-17  2.132633e-76
#
#             nyse_n_TD3_window_14_predictor_lstm  \
# value
# ADY_tstat                          9.684462e+00
# ADY_pvalue                         2.065841e-10
# SHA_tstat                          4.607036e+00
# SHA_pvalue                         2.511747e-07
# SOR_tstat                          9.678548e+00
# SOR_pvalue                         6.332642e-11
# MDD_tstat                          1.939845e+01
# MDD_pvalue                         3.149855e-63
#
#             nyse_n_TD3_window_14_predictor_lstm_rmr-pred
# value
# ADY_tstat                                       9.684462
# ADY_pvalue                                      1.000000
# SHA_tstat                                       4.607036
# SHA_pvalue                                      1.000000
# SOR_tstat                                       9.678548
# SOR_pvalue                                      1.000000
# MDD_tstat                                      19.398453
# MDD_pvalue                                      1.000000
